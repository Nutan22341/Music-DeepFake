# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Concatenate
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve
import pandas as pd

# Load both datasets
csv_path_1 = "/kaggle/input/embeddings-95-330/mert-v0-initial.csv"
csv_path_2 = "/kaggle/input/embeddings-95-330/mert-v1-330.csv"

df1 = pd.read_csv(csv_path_1).iloc[:, 1:]  # Remove first column if it's an index
df2 = pd.read_csv(csv_path_2).iloc[:, 1:]

# Ensure both have the 'label' column
if "label" not in df1.columns or "label" not in df2.columns:
    raise ValueError("One or both datasets do not contain a 'label' column.")

# Separate features and labels for each dataset
X1, y = df1.drop(columns=["label"]).values, df1["label"].values
X2 = df2.drop(columns=["label"]).values

# Ensure labels are the same across datasets
if not np.array_equal(y, df2["label"].values):
    raise ValueError("Mismatch in labels between datasets.")

# Split into train and test sets (70%-30%)
X1_train, X1_test, X2_train, X2_test, y_train, y_test = train_test_split(
    X1, X2, y, test_size=0.2, random_state=42, stratify=y
)

# Define CNN for Dataset 1
input1 = Input(shape=(X1.shape[1],))
x1 = tf.keras.layers.Reshape((X1.shape[1], 1))(input1)
x1 = Conv1D(32, kernel_size=3, activation='relu')(x1)
x1 = MaxPooling1D(pool_size=2)(x1)
x1 = Conv1D(64, kernel_size=3, activation='relu')(x1)
x1 = MaxPooling1D(pool_size=2)(x1)
x1 = Flatten()(x1)

# Define CNN for Dataset 2
input2 = Input(shape=(X2.shape[1],))
x2 = tf.keras.layers.Reshape((X2.shape[1], 1))(input2)
x2 = Conv1D(32, kernel_size=3, activation='relu')(x2)
x2 = MaxPooling1D(pool_size=2)(x2)
x2 = Conv1D(64, kernel_size=3, activation='relu')(x2)
x2 = MaxPooling1D(pool_size=2)(x2)
x2 = Flatten()(x2)

# Fusion: Concatenate CNN outputs
fused = Concatenate()([x1, x2])

# Fully Connected Network (FCN)
fcn = Dense(128, activation='relu')(fused)
fcn = Dropout(0.5)(fcn)
fcn = Dense(64, activation='relu')(fcn)
fcn = Dropout(0.3)(fcn)
output = Dense(1, activation='sigmoid')(fcn)

# Build and Compile the Model
model = Model(inputs=[input1, input2], outputs=output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the Model
model.fit([X1_train, X2_train], y_train, epochs=20, batch_size=32, validation_data=([X1_test, X2_test], y_test))

# Evaluate the Model
loss, accuracy = model.evaluate([X1_test, X2_test], y_test)
print(f"Test Accuracy: {accuracy:.4f}")

# Predictions and performance metrics
y_scores = model.predict([X1_test, X2_test])
y_pred = (y_scores > 0.5).astype(int)

# Classification Report
print("Classification Report:\n", classification_report(y_test, y_pred, digits=2))

# Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Calculate EER
def calculate_eer(y_test, y_scores):
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    fnr = 1 - tpr
    eer_threshold = thresholds[np.nanargmin(np.abs(fpr - fnr))]
    eer = fpr[np.nanargmin(np.abs(fpr - fnr))]
    return eer, eer_threshold

eer, eer_threshold = calculate_eer(y_test, y_scores)
print(f"EER: {eer:.4f} (Threshold: {eer_threshold:.4f})")
# Out:
# Epoch 1/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9862 - loss: 0.0374 - val_accuracy: 1.0000 - val_loss: 5.1501e-13
# Epoch 2/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 3.4049e-05 - val_accuracy: 1.0000 - val_loss: 4.6852e-23
# Epoch 3/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 4.6971e-06 - val_accuracy: 1.0000 - val_loss: 3.6990e-24
# Epoch 4/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.5276e-05 - val_accuracy: 1.0000 - val_loss: 2.1212e-25
# Epoch 5/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 2.0511e-06 - val_accuracy: 1.0000 - val_loss: 4.3409e-24
# Epoch 6/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 2.9156e-08 - val_accuracy: 1.0000 - val_loss: 5.3936e-24
# Epoch 7/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.1760e-08 - val_accuracy: 1.0000 - val_loss: 1.5070e-25
# Epoch 8/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.4638e-08 - val_accuracy: 1.0000 - val_loss: 2.9513e-27
# Epoch 9/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 5.1429e-06 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 10/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 2.7882e-08 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 11/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 12/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 2.9280e-10 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 13/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 3.7079e-08 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 14/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 4.8094e-11 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 15/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 3.5477e-09 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 16/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.0871e-08 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 17/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.1078e-09 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 18/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 3.0271e-09 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 19/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 6.8741e-10 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 20/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.1542e-09 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Test Accuracy: 1.0000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5534
#            1       1.00      1.00      1.00      1075
#
#     accuracy                           1.00      6609
#    macro avg       1.00      1.00      1.00      6609
# weighted avg       1.00      1.00      1.00      6609
#
# Confusion Matrix:
#  [[5534    0]
#  [   0 1075]]
# EER: 0.0000 (Threshold: 1.0000)

# %% [markdown]
# ### Concatinate the two models (Mert-v0 and Music2vec )

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Concatenate
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve
import pandas as pd


csv_path_1 = "/kaggle/input/embeddings-95-330/mert-v0-initial.csv"
csv_path_2 = "/kaggle/input/embeddings-95-330/m2v_merged_dataset.csv"

df1 = pd.read_csv(csv_path_1).iloc[:, 1:] 
df2 = pd.read_csv(csv_path_2).iloc[:, 1:]


if "label" not in df1.columns or "label" not in df2.columns:
    raise ValueError("One or both datasets do not contain a 'label' column.")


X1, y = df1.drop(columns=["label"]).values, df1["label"].values
X2 = df2.drop(columns=["label"]).values


if not np.array_equal(y, df2["label"].values):
    raise ValueError("Mismatch in labels between datasets.")

# Spliting into train and test sets (70%-30%)
X1_train, X1_test, X2_train, X2_test, y_train, y_test = train_test_split(
    X1, X2, y, test_size=0.2, random_state=42, stratify=y
)

# Define CNN for Dataset 1
input1 = Input(shape=(X1.shape[1],))
x1 = tf.keras.layers.Reshape((X1.shape[1], 1))(input1)
x1 = Conv1D(32, kernel_size=3, activation='relu')(x1)
x1 = MaxPooling1D(pool_size=2)(x1)
x1 = Conv1D(64, kernel_size=3, activation='relu')(x1)
x1 = MaxPooling1D(pool_size=2)(x1)
x1 = Flatten()(x1)

# Define CNN for Dataset 2
input2 = Input(shape=(X2.shape[1],))
x2 = tf.keras.layers.Reshape((X2.shape[1], 1))(input2)
x2 = Conv1D(32, kernel_size=3, activation='relu')(x2)
x2 = MaxPooling1D(pool_size=2)(x2)
x2 = Conv1D(64, kernel_size=3, activation='relu')(x2)
x2 = MaxPooling1D(pool_size=2)(x2)
x2 = Flatten()(x2)

# Fusion: Concatenate CNN outputs
fused = Concatenate()([x1, x2])

# Fully Connected Network (FCN)
fcn = Dense(128, activation='relu')(fused)
fcn = Dropout(0.5)(fcn)
fcn = Dense(64, activation='relu')(fcn)
fcn = Dropout(0.3)(fcn)
output = Dense(1, activation='sigmoid')(fcn)

# Build and Compile the Model
model = Model(inputs=[input1, input2], outputs=output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the Model
model.fit([X1_train, X2_train], y_train, epochs=20, batch_size=32, validation_data=([X1_test, X2_test], y_test))

# Evaluate the Model
loss, accuracy = model.evaluate([X1_test, X2_test], y_test)
print(f"Test Accuracy: {accuracy:.4f}")

# Predictions and performance metrics
y_scores = model.predict([X1_test, X2_test])
y_pred = (y_scores > 0.5).astype(int)

# Classification Report
print("Classification Report:\n", classification_report(y_test, y_pred, digits=2))

# Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Calculate EER
def calculate_eer(y_test, y_scores):
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    fnr = 1 - tpr
    eer_threshold = thresholds[np.nanargmin(np.abs(fpr - fnr))]
    eer = fpr[np.nanargmin(np.abs(fpr - fnr))]
    return eer, eer_threshold

eer, eer_threshold = calculate_eer(y_test, y_scores)
print(f"EER: {eer:.4f} (Threshold: {eer_threshold:.4f})")
# Out:
# Epoch 1/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.9919 - loss: 0.0184 - val_accuracy: 1.0000 - val_loss: 4.4407e-15
# Epoch 2/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 2.7076e-06 - val_accuracy: 1.0000 - val_loss: 1.8351e-19
# Epoch 3/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 3.9109e-06 - val_accuracy: 1.0000 - val_loss: 2.6789e-19
# Epoch 4/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 4.7672e-07 - val_accuracy: 1.0000 - val_loss: 1.1004e-21
# Epoch 5/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 4.3679e-08 - val_accuracy: 1.0000 - val_loss: 1.6489e-22
# Epoch 6/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 8.4673e-09 - val_accuracy: 1.0000 - val_loss: 9.4813e-23
# Epoch 7/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 1.2473e-08 - val_accuracy: 1.0000 - val_loss: 1.7374e-22
# Epoch 8/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 9.2147e-07 - val_accuracy: 1.0000 - val_loss: 9.0388e-29
# Epoch 9/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 2.0106e-09 - val_accuracy: 1.0000 - val_loss: 8.9008e-29
# Epoch 10/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 1.5833e-04 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 11/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9999 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 12/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 4.6853e-11 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 13/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 3.3958e-11 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 14/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 4.6303e-08 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 15/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 1.9271e-08 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 16/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 3.9567e-09 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 17/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 5.5689e-10 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 18/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 1.4087e-09 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 19/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 4.7280e-09 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 20/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 1.3779e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.1669e-42
# Test Accuracy: 1.0000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5534
#            1       1.00      1.00      1.00      1075
#
#     accuracy                           1.00      6609
#    macro avg       1.00      1.00      1.00      6609
# weighted avg       1.00      1.00      1.00      6609
#
# Confusion Matrix:
#  [[5534    0]
#  [   0 1075]]
# EER: 0.0000 (Threshold: 1.0000)

# %% [markdown]
# ### Concatinate the two models (Mert-v0 and Mert-95 )

# %%
# Load both datasets
csv_path_1 = "/kaggle/input/embeddings-95-330/mert-v0-initial.csv"
csv_path_2 = "/kaggle/input/embeddings-95-330/95_merged_dataset.csv"

df1 = pd.read_csv(csv_path_1).iloc[:, 1:]  # Remove first column if it's an index
df2 = pd.read_csv(csv_path_2).iloc[:, 1:]

# Ensure both have the 'label' column
if "label" not in df1.columns or "label" not in df2.columns:
    raise ValueError("One or both datasets do not contain a 'label' column.")

# Separate features and labels for each dataset
X1, y = df1.drop(columns=["label"]).values, df1["label"].values
X2 = df2.drop(columns=["label"]).values

# Ensure labels are the same across datasets
if not np.array_equal(y, df2["label"].values):
    raise ValueError("Mismatch in labels between datasets.")

# Split into train and test sets (70%-30%)
X1_train, X1_test, X2_train, X2_test, y_train, y_test = train_test_split(
    X1, X2, y, test_size=0.2, random_state=42, stratify=y
)

# Define CNN for Dataset 1
input1 = Input(shape=(X1.shape[1],))
x1 = tf.keras.layers.Reshape((X1.shape[1], 1))(input1)
x1 = Conv1D(32, kernel_size=3, activation='relu')(x1)
x1 = MaxPooling1D(pool_size=2)(x1)
x1 = Conv1D(64, kernel_size=3, activation='relu')(x1)
x1 = MaxPooling1D(pool_size=2)(x1)
x1 = Flatten()(x1)

# Define CNN for Dataset 2
input2 = Input(shape=(X2.shape[1],))
x2 = tf.keras.layers.Reshape((X2.shape[1], 1))(input2)
x2 = Conv1D(32, kernel_size=3, activation='relu')(x2)
x2 = MaxPooling1D(pool_size=2)(x2)
x2 = Conv1D(64, kernel_size=3, activation='relu')(x2)
x2 = MaxPooling1D(pool_size=2)(x2)
x2 = Flatten()(x2)

# Fusion: Concatenate CNN outputs
fused = Concatenate()([x1, x2])

# Fully Connected Network (FCN)
fcn = Dense(128, activation='relu')(fused)
fcn = Dropout(0.5)(fcn)
fcn = Dense(64, activation='relu')(fcn)
fcn = Dropout(0.3)(fcn)
output = Dense(1, activation='sigmoid')(fcn)

# Build and Compile the Model
model = Model(inputs=[input1, input2], outputs=output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the Model
model.fit([X1_train, X2_train], y_train, epochs=20, batch_size=32, validation_data=([X1_test, X2_test], y_test))

# Evaluate the Model
loss, accuracy = model.evaluate([X1_test, X2_test], y_test)
print(f"Test Accuracy: {accuracy:.4f}")

# Predictions and performance metrics
y_scores = model.predict([X1_test, X2_test])
y_pred = (y_scores > 0.5).astype(int)

# Classification Report
print("Classification Report:\n", classification_report(y_test, y_pred, digits=2))

# Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Calculate EER
def calculate_eer(y_test, y_scores):
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    fnr = 1 - tpr
    eer_threshold = thresholds[np.nanargmin(np.abs(fpr - fnr))]
    eer = fpr[np.nanargmin(np.abs(fpr - fnr))]
    return eer, eer_threshold

eer, eer_threshold = calculate_eer(y_test, y_scores)
print(f"EER: {eer:.4f} (Threshold: {eer_threshold:.4f})")
# Out:
# Epoch 1/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9917 - loss: 0.0175 - val_accuracy: 1.0000 - val_loss: 1.4095e-12
# Epoch 2/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 2.1330e-06 - val_accuracy: 1.0000 - val_loss: 3.3489e-14
# Epoch 3/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 7.3261e-07 - val_accuracy: 1.0000 - val_loss: 1.3977e-15
# Epoch 4/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 8.5116e-07 - val_accuracy: 1.0000 - val_loss: 1.5197e-17
# Epoch 5/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 1.4408e-07 - val_accuracy: 1.0000 - val_loss: 2.4926e-18
# Epoch 6/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 9.8873e-09 - val_accuracy: 1.0000 - val_loss: 9.6938e-19
# Epoch 7/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 7.4417e-05 - val_accuracy: 1.0000 - val_loss: 5.3842e-20
# Epoch 8/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 2.1407e-07 - val_accuracy: 1.0000 - val_loss: 2.5565e-20
# Epoch 9/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 6.2456e-09 - val_accuracy: 1.0000 - val_loss: 2.2098e-20
# Epoch 10/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 2.9000e-07 - val_accuracy: 1.0000 - val_loss: 2.5294e-22
# Epoch 11/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 1.4340e-09 - val_accuracy: 1.0000 - val_loss: 1.6667e-22
# Epoch 12/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 4.5360e-06 - val_accuracy: 1.0000 - val_loss: 5.3580e-27
# Epoch 13/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 4.2620e-12 - val_accuracy: 1.0000 - val_loss: 5.3382e-27
# Epoch 14/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 2.5553e-09 - val_accuracy: 1.0000 - val_loss: 3.6997e-27
# Epoch 15/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 1.4856e-11 - val_accuracy: 1.0000 - val_loss: 3.6819e-27
# Epoch 16/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 2.3882e-11 - val_accuracy: 1.0000 - val_loss: 3.5186e-27
# Epoch 17/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 1.3969e-10 - val_accuracy: 1.0000 - val_loss: 3.4400e-27
# Epoch 18/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 2.5272e-10 - val_accuracy: 1.0000 - val_loss: 2.9222e-27
# Epoch 19/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 1.5450e-10 - val_accuracy: 1.0000 - val_loss: 1.1566e-27
# Epoch 20/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 9.1877e-12 - val_accuracy: 1.0000 - val_loss: 1.1146e-27
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.2341e-28
# Test Accuracy: 1.0000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5534
#            1       1.00      1.00      1.00      1075
#
#     accuracy                           1.00      6609
#    macro avg       1.00      1.00      1.00      6609
# weighted avg       1.00      1.00      1.00      6609
#
# Confusion Matrix:
#  [[5534    0]
#  [   0 1075]]
# EER: 0.0000 (Threshold: 1.0000)

# %%
# Load both datasets
csv_path_1 = "/kaggle/input/embeddings-95-330/95_merged_dataset.csv"
csv_path_2 = "/kaggle/input/embeddings-95-330/m2v_merged_dataset.csv"

df1 = pd.read_csv(csv_path_1).iloc[:, 1:]  # Remove first column if it's an index
df2 = pd.read_csv(csv_path_2).iloc[:, 1:]

# Ensure both have the 'label' column
if "label" not in df1.columns or "label" not in df2.columns:
    raise ValueError("One or both datasets do not contain a 'label' column.")

# Separate features and labels for each dataset
X1, y = df1.drop(columns=["label"]).values, df1["label"].values
X2 = df2.drop(columns=["label"]).values

# Ensure labels are the same across datasets
if not np.array_equal(y, df2["label"].values):
    raise ValueError("Mismatch in labels between datasets.")

# Split into train and test sets (70%-30%)
X1_train, X1_test, X2_train, X2_test, y_train, y_test = train_test_split(
    X1, X2, y, test_size=0.2, random_state=42, stratify=y
)

# Define CNN for Dataset 1
input1 = Input(shape=(X1.shape[1],))
x1 = tf.keras.layers.Reshape((X1.shape[1], 1))(input1)
x1 = Conv1D(32, kernel_size=3, activation='relu')(x1)
x1 = MaxPooling1D(pool_size=2)(x1)
x1 = Conv1D(64, kernel_size=3, activation='relu')(x1)
x1 = MaxPooling1D(pool_size=2)(x1)
x1 = Flatten()(x1)

# Define CNN for Dataset 2
input2 = Input(shape=(X2.shape[1],))
x2 = tf.keras.layers.Reshape((X2.shape[1], 1))(input2)
x2 = Conv1D(32, kernel_size=3, activation='relu')(x2)
x2 = MaxPooling1D(pool_size=2)(x2)
x2 = Conv1D(64, kernel_size=3, activation='relu')(x2)
x2 = MaxPooling1D(pool_size=2)(x2)
x2 = Flatten()(x2)

# Fusion: Concatenate CNN outputs
fused = Concatenate()([x1, x2])

# Fully Connected Network (FCN)
fcn = Dense(128, activation='relu')(fused)
fcn = Dropout(0.5)(fcn)
fcn = Dense(64, activation='relu')(fcn)
fcn = Dropout(0.3)(fcn)
output = Dense(1, activation='sigmoid')(fcn)

# Build and Compile the Model
model = Model(inputs=[input1, input2], outputs=output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the Model
model.fit([X1_train, X2_train], y_train, epochs=20, batch_size=32, validation_data=([X1_test, X2_test], y_test))

# Evaluate the Model
loss, accuracy = model.evaluate([X1_test, X2_test], y_test)
print(f"Test Accuracy: {accuracy:.4f}")

# Predictions and performance metrics
y_scores = model.predict([X1_test, X2_test])
y_pred = (y_scores > 0.5).astype(int)

# Classification Report
print("Classification Report:\n", classification_report(y_test, y_pred, digits=2))

# Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Calculate EER
def calculate_eer(y_test, y_scores):
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    fnr = 1 - tpr
    eer_threshold = thresholds[np.nanargmin(np.abs(fpr - fnr))]
    eer = fpr[np.nanargmin(np.abs(fpr - fnr))]
    return eer, eer_threshold

eer, eer_threshold = calculate_eer(y_test, y_scores)
print(f"EER: {eer:.4f} (Threshold: {eer_threshold:.4f})")
# Out:
# Epoch 1/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.9769 - loss: 0.0542 - val_accuracy: 1.0000 - val_loss: 6.8771e-08
# Epoch 2/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 2.2568e-04 - val_accuracy: 1.0000 - val_loss: 7.7833e-12
# Epoch 3/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 2.3767e-04 - val_accuracy: 1.0000 - val_loss: 7.3404e-14
# Epoch 4/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 1.3594e-04 - val_accuracy: 1.0000 - val_loss: 1.4611e-11
# Epoch 5/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9999 - loss: 1.3829e-04 - val_accuracy: 1.0000 - val_loss: 1.4775e-14
# Epoch 6/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 2.4546e-06 - val_accuracy: 1.0000 - val_loss: 4.8012e-17
# Epoch 7/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 4.9503e-05 - val_accuracy: 1.0000 - val_loss: 3.0100e-18
# Epoch 8/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 3.3769e-05 - val_accuracy: 1.0000 - val_loss: 4.1009e-17
# Epoch 9/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 1.4107e-05 - val_accuracy: 1.0000 - val_loss: 3.9479e-18
# Epoch 10/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 2.2312e-05 - val_accuracy: 1.0000 - val_loss: 2.3198e-18
# Epoch 11/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 2.9060e-05 - val_accuracy: 1.0000 - val_loss: 1.1131e-20
# Epoch 12/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 1.5156e-05 - val_accuracy: 1.0000 - val_loss: 3.1612e-22
# Epoch 13/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 3.1437e-06 - val_accuracy: 1.0000 - val_loss: 8.4415e-23
# Epoch 14/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 2.6838e-07 - val_accuracy: 1.0000 - val_loss: 7.3769e-19
# Epoch 15/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 1.2727e-04 - val_accuracy: 1.0000 - val_loss: 6.0847e-07
# Epoch 16/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 2.1652e-05 - val_accuracy: 1.0000 - val_loss: 8.4310e-16
# Epoch 17/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 6.4100e-06 - val_accuracy: 1.0000 - val_loss: 2.6108e-15
# Epoch 18/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 4.7943e-07 - val_accuracy: 1.0000 - val_loss: 1.6081e-15
# Epoch 19/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 6.7856e-07 - val_accuracy: 1.0000 - val_loss: 3.1129e-16
# Epoch 20/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 1.9562e-06 - val_accuracy: 1.0000 - val_loss: 4.5535e-21
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 6.5224e-22
# Test Accuracy: 1.0000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5534
#            1       1.00      1.00      1.00      1075
#
#     accuracy                           1.00      6609
#    macro avg       1.00      1.00      1.00      6609
# weighted avg       1.00      1.00      1.00      6609
#
# Confusion Matrix:
#  [[5534    0]
#  [   0 1075]]
# EER: 0.0000 (Threshold: 1.0000)

# %% [markdown]
# ### Concatinate the two models (Mert-95 and Music2vec )

# %%
# Load both datasets
csv_path_1 = "/kaggle/input/embeddings-95-330/95_merged_dataset.csv"
csv_path_2 = "/kaggle/input/embeddings-95-330/mert-v1-330.csv"

df1 = pd.read_csv(csv_path_1).iloc[:, 1:]  # Remove first column if it's an index
df2 = pd.read_csv(csv_path_2).iloc[:, 1:]

# Ensure both have the 'label' column
if "label" not in df1.columns or "label" not in df2.columns:
    raise ValueError("One or both datasets do not contain a 'label' column.")

# Separate features and labels for each dataset
X1, y = df1.drop(columns=["label"]).values, df1["label"].values
X2 = df2.drop(columns=["label"]).values

# Ensure labels are the same across datasets
if not np.array_equal(y, df2["label"].values):
    raise ValueError("Mismatch in labels between datasets.")

# Split into train and test sets (70%-30%)
X1_train, X1_test, X2_train, X2_test, y_train, y_test = train_test_split(
    X1, X2, y, test_size=0.2, random_state=42, stratify=y
)

# Define CNN for Dataset 1
input1 = Input(shape=(X1.shape[1],))
x1 = tf.keras.layers.Reshape((X1.shape[1], 1))(input1)
x1 = Conv1D(32, kernel_size=3, activation='relu')(x1)
x1 = MaxPooling1D(pool_size=2)(x1)
x1 = Conv1D(64, kernel_size=3, activation='relu')(x1)
x1 = MaxPooling1D(pool_size=2)(x1)
x1 = Flatten()(x1)

# Define CNN for Dataset 2
input2 = Input(shape=(X2.shape[1],))
x2 = tf.keras.layers.Reshape((X2.shape[1], 1))(input2)
x2 = Conv1D(32, kernel_size=3, activation='relu')(x2)
x2 = MaxPooling1D(pool_size=2)(x2)
x2 = Conv1D(64, kernel_size=3, activation='relu')(x2)
x2 = MaxPooling1D(pool_size=2)(x2)
x2 = Flatten()(x2)

# Fusion: Concatenate CNN outputs
fused = Concatenate()([x1, x2])

# Fully Connected Network (FCN)
fcn = Dense(128, activation='relu')(fused)
fcn = Dropout(0.5)(fcn)
fcn = Dense(64, activation='relu')(fcn)
fcn = Dropout(0.3)(fcn)
output = Dense(1, activation='sigmoid')(fcn)

# Build and Compile the Model
model = Model(inputs=[input1, input2], outputs=output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the Model
model.fit([X1_train, X2_train], y_train, epochs=20, batch_size=32, validation_data=([X1_test, X2_test], y_test))

# Evaluate the Model
loss, accuracy = model.evaluate([X1_test, X2_test], y_test)
print(f"Test Accuracy: {accuracy:.4f}")

# Predictions and performance metrics
y_scores = model.predict([X1_test, X2_test])
y_pred = (y_scores > 0.5).astype(int)

# Classification Report
print("Classification Report:\n", classification_report(y_test, y_pred, digits=2))

# Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Calculate EER
def calculate_eer(y_test, y_scores):
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    fnr = 1 - tpr
    eer_threshold = thresholds[np.nanargmin(np.abs(fpr - fnr))]
    eer = fpr[np.nanargmin(np.abs(fpr - fnr))]
    return eer, eer_threshold

eer, eer_threshold = calculate_eer(y_test, y_scores)
print(f"EER: {eer:.4f} (Threshold: {eer_threshold:.4f})")
# Out:
# Epoch 1/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - accuracy: 0.9830 - loss: 0.0514 - val_accuracy: 1.0000 - val_loss: 1.4310e-09
# Epoch 2/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 8.0856e-05 - val_accuracy: 1.0000 - val_loss: 2.1469e-12
# Epoch 3/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 2.5366e-05 - val_accuracy: 1.0000 - val_loss: 4.6870e-15
# Epoch 4/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9999 - loss: 3.4181e-04 - val_accuracy: 1.0000 - val_loss: 1.7934e-14
# Epoch 5/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 6.2574e-05 - val_accuracy: 1.0000 - val_loss: 5.8724e-16
# Epoch 6/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.1243e-05 - val_accuracy: 1.0000 - val_loss: 1.1182e-18
# Epoch 7/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9999 - loss: 5.1300e-04 - val_accuracy: 1.0000 - val_loss: 3.1373e-11
# Epoch 8/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 2.0334e-05 - val_accuracy: 1.0000 - val_loss: 4.2555e-16
# Epoch 9/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9999 - loss: 1.5860e-04 - val_accuracy: 1.0000 - val_loss: 3.4304e-17
# Epoch 10/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 8.7493e-06 - val_accuracy: 1.0000 - val_loss: 2.6793e-17
# Epoch 11/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.1422e-05 - val_accuracy: 1.0000 - val_loss: 2.4818e-18
# Epoch 12/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.5617e-06 - val_accuracy: 1.0000 - val_loss: 7.5651e-20
# Epoch 13/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 3.6463e-07 - val_accuracy: 1.0000 - val_loss: 1.1556e-19
# Epoch 14/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 8.9735e-06 - val_accuracy: 1.0000 - val_loss: 4.9029e-21
# Epoch 15/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.0746e-07 - val_accuracy: 1.0000 - val_loss: 8.9596e-22
# Epoch 16/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.0927e-04 - val_accuracy: 1.0000 - val_loss: 1.1617e-22
# Epoch 17/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.5788e-08 - val_accuracy: 1.0000 - val_loss: 3.9210e-23
# Epoch 18/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.3094e-08 - val_accuracy: 1.0000 - val_loss: 7.5922e-24
# Epoch 19/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 3.0676e-08 - val_accuracy: 1.0000 - val_loss: 1.1216e-24
# Epoch 20/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 2.1829e-08 - val_accuracy: 1.0000 - val_loss: 1.2843e-25
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.4940e-25
# Test Accuracy: 1.0000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5534
#            1       1.00      1.00      1.00      1075
#
#     accuracy                           1.00      6609
#    macro avg       1.00      1.00      1.00      6609
# weighted avg       1.00      1.00      1.00      6609
#
# Confusion Matrix:
#  [[5534    0]
#  [   0 1075]]
# EER: 0.0000 (Threshold: 1.0000)

# %% [markdown]
# ### Concatinate the two models (Music2vec and Mert-v1-330 )

# %%
# Load both datasets
csv_path_1 = "/kaggle/input/embeddings-95-330/m2v_merged_dataset.csv"
csv_path_2 = "/kaggle/input/embeddings-95-330/mert-v1-330.csv"

df1 = pd.read_csv(csv_path_1).iloc[:, 1:]  # Remove first column if it's an index
df2 = pd.read_csv(csv_path_2).iloc[:, 1:]

# Ensure both have the 'label' column
if "label" not in df1.columns or "label" not in df2.columns:
    raise ValueError("One or both datasets do not contain a 'label' column.")

# Separate features and labels for each dataset
X1, y = df1.drop(columns=["label"]).values, df1["label"].values
X2 = df2.drop(columns=["label"]).values

# Ensure labels are the same across datasets
if not np.array_equal(y, df2["label"].values):
    raise ValueError("Mismatch in labels between datasets.")

# Split into train and test sets (70%-30%)
X1_train, X1_test, X2_train, X2_test, y_train, y_test = train_test_split(
    X1, X2, y, test_size=0.2, random_state=42, stratify=y
)

# Define CNN for Dataset 1
input1 = Input(shape=(X1.shape[1],))
x1 = tf.keras.layers.Reshape((X1.shape[1], 1))(input1)
x1 = Conv1D(32, kernel_size=3, activation='relu')(x1)
x1 = MaxPooling1D(pool_size=2)(x1)
x1 = Conv1D(64, kernel_size=3, activation='relu')(x1)
x1 = MaxPooling1D(pool_size=2)(x1)
x1 = Flatten()(x1)

# Define CNN for Dataset 2
input2 = Input(shape=(X2.shape[1],))
x2 = tf.keras.layers.Reshape((X2.shape[1], 1))(input2)
x2 = Conv1D(32, kernel_size=3, activation='relu')(x2)
x2 = MaxPooling1D(pool_size=2)(x2)
x2 = Conv1D(64, kernel_size=3, activation='relu')(x2)
x2 = MaxPooling1D(pool_size=2)(x2)
x2 = Flatten()(x2)

# Fusion: Concatenate CNN outputs
fused = Concatenate()([x1, x2])

# Fully Connected Network (FCN)
fcn = Dense(128, activation='relu')(fused)
fcn = Dropout(0.5)(fcn)
fcn = Dense(64, activation='relu')(fcn)
fcn = Dropout(0.3)(fcn)
output = Dense(1, activation='sigmoid')(fcn)

# Build and Compile the Model
model = Model(inputs=[input1, input2], outputs=output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the Model
model.fit([X1_train, X2_train], y_train, epochs=20, batch_size=32, validation_data=([X1_test, X2_test], y_test))

# Evaluate the Model
loss, accuracy = model.evaluate([X1_test, X2_test], y_test)
print(f"Test Accuracy: {accuracy:.4f}")

# Predictions and performance metrics
y_scores = model.predict([X1_test, X2_test])
y_pred = (y_scores > 0.5).astype(int)

# Classification Report
print("Classification Report:\n", classification_report(y_test, y_pred, digits=2))

# Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Calculate EER
def calculate_eer(y_test, y_scores):
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    fnr = 1 - tpr
    eer_threshold = thresholds[np.nanargmin(np.abs(fpr - fnr))]
    eer = fpr[np.nanargmin(np.abs(fpr - fnr))]
    return eer, eer_threshold

eer, eer_threshold = calculate_eer(y_test, y_scores)
print(f"EER: {eer:.4f} (Threshold: {eer_threshold:.4f})")
# Out:
# Epoch 1/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 16s 12ms/step - accuracy: 0.9764 - loss: 0.0563 - val_accuracy: 1.0000 - val_loss: 6.5830e-10
# Epoch 2/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9999 - loss: 3.0159e-04 - val_accuracy: 1.0000 - val_loss: 1.2089e-12
# Epoch 3/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 7.6629e-05 - val_accuracy: 1.0000 - val_loss: 2.9831e-16
# Epoch 4/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9999 - loss: 1.9528e-04 - val_accuracy: 1.0000 - val_loss: 1.1165e-12
# Epoch 5/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 2.9421e-05 - val_accuracy: 1.0000 - val_loss: 2.5135e-13
# Epoch 6/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 4.2164e-05 - val_accuracy: 1.0000 - val_loss: 2.2790e-14
# Epoch 7/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 3.7223e-05 - val_accuracy: 1.0000 - val_loss: 1.4230e-14
# Epoch 8/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.7430e-06 - val_accuracy: 1.0000 - val_loss: 8.1712e-16
# Epoch 9/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 3.9075e-05 - val_accuracy: 1.0000 - val_loss: 2.0380e-16
# Epoch 10/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 6.4596e-05 - val_accuracy: 0.9998 - val_loss: 4.1344e-04
# Epoch 11/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9991 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 1.5617e-12
# Epoch 12/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.6052e-05 - val_accuracy: 1.0000 - val_loss: 1.3406e-15
# Epoch 13/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 3.3741e-05 - val_accuracy: 1.0000 - val_loss: 2.0834e-15
# Epoch 14/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 1.1469e-06 - val_accuracy: 1.0000 - val_loss: 2.2547e-16
# Epoch 15/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9995 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 4.1283e-19
# Epoch 16/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 4.5841e-06 - val_accuracy: 1.0000 - val_loss: 4.5681e-19
# Epoch 17/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 5.0862e-08 - val_accuracy: 1.0000 - val_loss: 2.4714e-21
# Epoch 18/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 6.8969e-07 - val_accuracy: 1.0000 - val_loss: 1.5466e-21
# Epoch 19/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 2.6813e-05 - val_accuracy: 1.0000 - val_loss: 4.9364e-21
# Epoch 20/20
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 2.8957e-06 - val_accuracy: 1.0000 - val_loss: 6.4674e-31
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.3952e-31
# Test Accuracy: 1.0000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5534
#            1       1.00      1.00      1.00      1075
#
#     accuracy                           1.00      6609
#    macro avg       1.00      1.00      1.00      6609
# weighted avg       1.00      1.00      1.00      6609
#
# Confusion Matrix:
#  [[5534    0]
#  [   0 1075]]
# EER: 0.0000 (Threshold: 1.0000)
